# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
df = pd.read_csv("student-mat.csv", sep=";")
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
features = [ "school", "sex", "age", "address", "traveltime", "studytime", "failures", "schoolsup", "famsup", "paid", "activities", "higher", "internet", "romantic", "famrel", "freetime", "goout", "health", "absences", "G1", "G2" ]

# %%
X = df[features]
X = pd.get_dummies(X)
y = df["G3"]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_valid)

mse = mean_squared_error(y_valid, y_pred)
r2 = r2_score(y_valid, y_pred)
mae = mean_absolute_error(y_valid, y_pred)

print(f"MSE:  {mse:.2f}")
print(f"MAE:  {mae:.2f}")
print(f"R²:   {r2:.2f}")
# Out:
# MSE:  3.27
# MAE:  1.19
# R²:   0.82

# %%
fig, axes = plt.subplots(figsize=(15, 12))
fig.suptitle('Model Performance: Predicted vs Actual Values', fontsize=16)
y_actual = y_valid
y_predicted = y_pred
axes.scatter(y_actual, y_predicted, alpha=0.6, color='blue')
axes.plot([y_actual.min(), y_actual.max()], [y_actual.min(), y_actual.max()], 'r--', lw=2)
axes.set_xlabel('Actual Values')
axes.set_ylabel('Predicted Values')
axes.set_title('Predicted vs Actual Values')
axes.grid(True, alpha=0.3)

ax.set_xlim(min_val, max_val)
ax.set_ylim(min_val, max_val)
ax.set_aspect('equal', 'box')
ticks = np.linspace(min_val, max_val, 10)
ax.set_xticks(ticks)
ax.set_yticks(ticks)


# Add R² score to the plot
r2 = r2_score(y_actual, y_predicted)
axes.text(0.05, 0.95, f'R² = {r2:.3f}', transform=axes.transAxes, 
                bbox=dict(boxstyle="round,pad=0.3", facecolor="yellow", alpha=0.7))
# Out:
# Text(0.05, 0.95, 'R² = 0.820')

# %%
print(y_valid, y_pred)
# Out:
# 174     9
# 92      6
# 367     0
# 56     15
# 322    11
#        ..
# 229    12
# 136     0
# 315    11
# 245    18
# 152    10
# Name: G3, Length: 99, dtype: int64 [10.89777421  5.90226032  5.59380421 14.99738797  9.83480842 13.65826736
#   3.59349878 19.28047595 10.97812519 10.54570618  8.80120835 15.9996546
#  12.25012882 19.06802501  8.40259785  9.00727555 10.30093333  6.15043629
#  14.58441655 10.76114967  6.19003224 15.10094791 14.57029498 -2.03709161
#  10.47081393 14.20043636  6.31020969 15.01862455 12.38066815 16.6985085
#   8.93984823  9.69610404  4.16301369 12.90749722  3.7649803  10.74537529
#  12.01090249 10.58208805 13.72448805  7.29573493 12.60440867  5.36199951
#  -1.23301164  8.39218181 11.82608529  8.82662325 11.93451359 12.67389069
#   9.16386826  6.45753592  8.03247609  8.40700491  3.3641231  11.7114727
#  11.67634929 13.96706545 15.29301846 11.26817202  9.05727129  7.05559267
#  11.43197679 12.37840926 13.52234103  4.84466432  9.67290178  8.54584557
# ...
